# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/GPT-Finetuning/blob/main/31-LlamaIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama-index

# %%
# !mkdir data

# %%
import os
# from llama_index import VectorStoreIndex, SimpleWebPageReader
# Enter your OpenAI key below:
os.environ["OPENAI_API_KEY"] = "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"

# %%
# !pip install pypdf

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader

documents = SimpleDirectoryReader("./data").load_data()
index = VectorStoreIndex.from_documents(documents)
# https://faiss.ai/index.html 적용 시 수정 필요
# Out:
# WARNING:pypdf.generic._base:could not convert string to float: '0.00-50' : FloatObject (b'0.00-50') invalid; use 0.0 instead
# WARNING:pypdf.generic._base:could not convert string to float: '0.00-50' : FloatObject (b'0.00-50') invalid; use 0.0 instead
# WARNING:pypdf.generic._base:could not convert string to float: '0.00-50' : FloatObject (b'0.00-50') invalid; use 0.0 instead
# WARNING:pypdf.generic._base:could not convert string to float: '0.00-50' : FloatObject (b'0.00-50') invalid; use 0.0 instead
# WARNING:pypdf.generic._base:could not convert string to float: '0.00-50' : FloatObject (b'0.00-50') invalid; use 0.0 instead
# WARNING:pypdf.generic._base:could not convert string to float: '0.00-20' : FloatObject (b'0.00-20') invalid; use 0.0 instead
# WARNING:pypdf.generic._base:could not convert string to float: '0.00-20' : FloatObject (b'0.00-20') invalid; use 0.0 instead
# ...

# %% [markdown]
# ### file : ECOPRO-20230814-9pages.pdf

# %%
query_engine = index.as_query_engine()
query_engine.query("What is the author name? in short answer")

# %%
query_engine.query("에코프로 반기 사업보고서 내용을 발표자료로 요약 정리")

# %%
query_engine.query("재무 상태 내용 요약")

# %%
query_engine.query("신용 평가 내용 요약")

# %% [markdown]
# ### file : 08.Network.pdf

# %%
query_engine.query("network 내용을 발표자료 요약 정리")
# Out:
# Response(response='발표자료 요약 정리에는 다음과 같은 내용이 포함될 수 있습니다:\n- 네트워크는 통신을 위한 단말, 링크, 노드의 집합입니다.\n- 랜(LAN)이나 모뎀과 같은 통신 설비를 갖춘 컴퓨터를 서로 연결하여 통신을 가능하게 하는 조직이나 체계입니다.\n- 33페이지에서는 위성 연결에 대한 내용이 있습니다.', source_nodes=[NodeWithScore(node=TextNode(id_='6d73ebe3-83b8-4105-b3d2-11323566156b', embedding=None, metadata={'page_label': '11', 'file_name': 'Network.pdf', 'file_path': 'data/Network.pdf', 'file_type': 'application/pdf', 'file_size': 2661126, 'creation_date': '2024-01-07', 'last_modified_date': '2024-01-07', 'last_accessed_date': '2024-01-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c7f70dac-7a56-4d6c-88a7-23b804b38498', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '11', 'file_name': 'Netw
# ...

# %%
query_engine.query("network에 대한 작성자는")
# Out:
# Response(response='작성자에 대한 정보가 주어지지 않았으므로, network에 대한 작성자를 알 수 없습니다.', source_nodes=[NodeWithScore(node=TextNode(id_='08fa12e6-5f49-4825-8080-448bc2440078', embedding=None, metadata={'page_label': '33', 'file_name': 'Network.pdf', 'file_path': 'data/Network.pdf', 'file_type': 'application/pdf', 'file_size': 2661126, 'creation_date': '2024-01-07', 'last_modified_date': '2024-01-07', 'last_accessed_date': '2024-01-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f2034646-8b47-4175-bfb4-56889b0c924f', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '33', 'file_name': 'Network.pdf', 'file_path': 'data/Network.pdf', 'file_type': 'application/pdf', 'file_size': 2661126, 'creation_date': '202
# ...

# %% [markdown]
# ### file : 08.Web Framework - python.pdf

# %%
rval = query_engine.query("python에 대한 설명")

# %%
rval
# Out:
# Response(response='Python은 프로그래밍 언어로, 다양한 용도로 사용됩니다. Python은 간결하고 읽기 쉬운 문법을 가지고 있어 입문자에게 적합하며, 동시에 강력한 기능을 제공하여 전문 개발자들도 많이 사용합니다. Python은 다양한 분야에서 사용되며, 웹 개발, 데이터 분석, 인공지능, 자동화 등 다양한 영역에서 활용됩니다. Python은 또한 다양한 라이브러리와 프레임워크를 제공하여 개발자들이 빠르고 효율적으로 개발할 수 있도록 도와줍니다.', source_nodes=[NodeWithScore(node=TextNode(id_='5bd8f1be-c9db-416a-9acf-806248bd9ae9', embedding=None, metadata={'page_label': '4', 'file_name': 'WebFramework_python.pdf', 'file_path': 'data/WebFramework_python.pdf', 'file_type': 'application/pdf', 'file_size': 401911, 'creation_date': '2024-01-07', 'last_modified_date': '2024-01-07', 'last_accessed_date': '2024-01-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c79372b2-3ea6-4249-a8bc-3284
# ...

# %%
rval.response
# Out:
# 'Python은 인터프리터식, 객체지향적, 동적 타이핑 대화형 프로그래밍 언어입니다. 파이썬은 간결하고 가독성이 높은 문법을 가지고 있으며, 다양한 운영 체제에서 사용할 수 있습니다. 파이썬은 다양한 분야에서 사용되며, 웹 개발, 데이터 분석, 인공지능, 자동화 등 다양한 용도로 활용됩니다. 파이썬은 많은 개발자들에게 인기가 있으며, 다양한 라이브러리와 프레임워크가 있어 개발을 더욱 편리하게 할 수 있습니다.'

# %%
rval.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='ba83a6ad-94e1-43c3-82c6-ddf09c2e3db7', embedding=None, metadata={'page_label': '4', 'file_name': 'ECOPRO-20230814-9pages.pdf', 'file_path': 'data/ECOPRO-20230814-9pages.pdf', 'file_type': 'application/pdf', 'file_size': 502761, 'creation_date': '2024-01-07', 'last_modified_date': '2024-01-07', 'last_accessed_date': '2024-01-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='471d6afc-f9e4-42db-92a5-fd324a1dcfbb', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '4', 'file_name': 'ECOPRO-20230814-9pages.pdf', 'file_path': 'data/ECOPRO-20230814-9pages.pdf', 'file_type': 'application/pdf', 'file_size': 502761, 'creation_date': '2024-01-07', 'last_modified_date
# ...
